# %%
load('incidence_coloring.py')
G = graphs.DegreeSequence([4,4,4,4,4])
G.show()
C = incidence_coloring(G,true)
print _check_is_proper_incidence_coloring(C)
(G.to_directed()).plot(edge_colors=C)
# Out:
# Graphics object consisting of 16 graphics primitives
# True
# Graphics object consisting of 30 graphics primitives

# %%
load('incidence_coloring.py')
G = graphs.DegreeSequence([4,4,4,4,4,4,4,4,4])
G.show()
C = incidence_coloring(G,true)
print _check_is_proper_incidence_coloring(C)
(G.to_directed()).plot(edge_colors=C)
# Out:
# Graphics object consisting of 28 graphics primitives
# True
# Graphics object consisting of 54 graphics primitives

# %%
load('incidence_coloring.py')
G = Graph({1:[2,3,4,5],2:[3,4,5],3:[4,5]})
G.show()
C = incidence_coloring(G,true)
print _check_is_proper_incidence_coloring(C)
(G.to_directed()).plot(edge_colors=C)
# Out:
# Graphics object consisting of 15 graphics primitives
# True
# Graphics object consisting of 28 graphics primitives

# %%
load('incidence_coloring.py')
G = Graph({2:[1,3,4,10],3:[4,5],6:[4,9,8],7:[5,6,8],8:[4,5], 9:[1,10]})
G.show()
C = incidence_coloring(G,true)
print _check_is_proper_incidence_coloring(C)
(G.to_directed()).plot(edge_colors=C)
# Out:
# Graphics object consisting of 27 graphics primitives
# True
# Graphics object consisting of 52 graphics primitives

# %%
load('incidence_coloring.py')
G = graphs.DegreeSequence([3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3])
G.show()
C = incidence_coloring(G)
print C
print _check_is_proper_incidence_coloring(C)
# Out:
# Graphics object consisting of 81 graphics primitives
# {1: [(10, 8), (21, 20), (3, 2), (25, 24), (29, 28), (17, 16), (18, 19), (14, 12), (30, 28), (6, 4), (22, 20), (11, 9), (13, 12), (1, 0)], 2: [(1, 3), (28, 29), (27, 26), (30, 31), (22, 23), (16, 17), (9, 11), (15, 14), (10, 11), (12, 14), (20, 21), (19, 18), (4, 6), (2, 3)], 3: [(9, 8), (7, 6), (20, 22), (21, 23), (3, 1), (11, 10), (28, 30), (29, 31), (5, 4), (26, 27), (24, 25), (2, 0)], 4: [(19, 17), (27, 25), (31, 29), (4, 5), (7, 5), (0, 1), (15, 13), (12, 13), (24, 26), (8, 9), (23, 21), (16, 18)], 5: [(31, 30), (6, 7), (18, 16), (8, 10), (13, 15), (26, 24), (23, 22), (25, 27), (17, 19), (14, 15), (5, 7), (0, 2)], 6: [(11, 8), (2, 1), (0, 3), (25, 26), (29, 30), (28, 31), (27, 24), (19, 16), (20, 23), (9, 10), (6, 5), (12, 15), (13, 14), (17, 18), (7, 4), (22, 21)], 7: [(4, 7), (3, 0), (5, 6), (26, 25), (1, 2), (24, 27), (18, 17), (10, 9), (15, 12), (8, 11), (30, 29), (14, 13), (16, 19), (31, 28), (23, 20), (21, 22)]}
# True

# %%
load('incidence_coloring_degree3.py')
G = graphs.CycleGraph(5)
G.show()
C = incidence_coloring(G,true)
(G.to_directed()).plot(edge_colors=C)
# Out:
# Graphics object consisting of 11 graphics primitives
# Graphics object consisting of 20 graphics primitives

# %%
load('incidence_coloring.py')
G = graphs.PetersenGraph()
G.show()
C = incidence_coloring(G,true)
(G.to_directed()).plot(edge_colors=C)
# Out:
# Graphics object consisting of 26 graphics primitives
# Graphics object consisting of 50 graphics primitives

# %%
load('incidence_coloring.py')
G = graphs.DegreeSequence([3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3])
G.show()
C = incidence_coloring(G)
print C
print _check_is_proper_incidence_coloring(C)
# Out:
# Graphics object consisting of 76 graphics primitives
# {1: [(9, 8), (25, 23), (16, 17), (24, 23), (5, 3), (15, 17), (19, 21), (20, 21), (10, 8), (13, 12), (28, 27), (1, 0), (26, 27), (4, 6), (14, 12), (2, 3)], 2: [(27, 28), (3, 2), (21, 19), (12, 13), (8, 9), (20, 22), (1, 2), (26, 29), (17, 15), (6, 4), (23, 24), (14, 11)], 3: [(27, 26), (28, 29), (22, 20), (21, 20), (8, 10), (23, 25), (12, 14), (6, 0), (11, 14), (2, 1), (17, 16), (18, 16), (7, 10), (3, 5)], 4: [(19, 22), (7, 9), (4, 5), (0, 1), (18, 15), (11, 13), (24, 25)], 5: [(22, 19), (10, 7), (29, 26), (25, 24), (0, 6), (29, 28), (13, 11), (16, 18), (9, 7), (5, 4), (15, 18)], 6: [(7, 8), (23, 26), (27, 29), (11, 12), (0, 4), (17, 14), (13, 10), (20, 19), (9, 6), (28, 24), (22, 25), (15, 16), (3, 1), (21, 18), (5, 2)], 7: [(6, 9), (1, 3), (8, 7), (26, 23), (14, 17), (2, 5), (25, 22), (19, 20), (4, 0), (16, 15), (29, 27), (24, 28), (10, 13), (12, 11), (18, 21)]}
# True

# %%
load('incidence_coloring.py')
G = Graph({2:[1,3,4],3:[4,5],6:[4,9,8],7:[5,8],8:[5], 9:[1,10]})
G.show()
C = incidence_coloring(G,true)
print _check_is_proper_incidence_coloring(C)
(G.to_directed()).plot(edge_colors=C)
# Out:
# Graphics object consisting of 24 graphics primitives
# True
# Graphics object consisting of 46 graphics primitives

# %%
load('incidence_coloring.py')
G =  Graph({11: [13,12,14], 12:[13,14], 15: [13,14,0], 21: [23,22,24], 22:[23,24], 25: [23,24,0], 31: [33,32,34], 32:[33,34], 35: [33,34,0]})
G.show()
C = incidence_coloring(G)
print C
print _check_is_proper_incidence_coloring(C)
# Out:
# Graphics object consisting of 41 graphics primitives
# {1: [(35, 34), (0, 15), (12, 14), (22, 24), (25, 24), (31, 33), (11, 13)], 2: [(34, 35), (24, 22), (25, 23), (13, 11), (12, 11), (21, 22), (0, 35), (33, 31)], 3: [(32, 33), (15, 0), (22, 21), (35, 0), (11, 12), (34, 31), (24, 25), (14, 12), (23, 25)], 4: [(31, 34), (12, 13), (23, 21), (32, 34), (15, 14)], 5: [(33, 32), (13, 12), (34, 32), (21, 23), (14, 15)], 6: [(23, 22), (13, 15), (25, 0), (33, 35), (11, 14), (31, 32), (21, 24)], 7: [(14, 11), (15, 13), (22, 23), (32, 31), (0, 25), (35, 33), (24, 21)]}
# True

# %%
load('incidence_coloring.py')
for i in range(0,100):
    G =  graphs.RandomRegular(3,100)
    if G.connected_components_number() > 1:
        continue
    C = incidence_coloring(G)
    if not _check_is_proper_incidence_coloring(C):
        print "ERROR:"
        print G.edges()
print "finished"
# Out:
# finished

# %%
load('incidence_coloring.py')
G = graphs.DegreeSequence([3,3,3,3,3,3,3,3])
G.show()
C = incidence_coloring(G)
print C
print _check_is_proper_incidence_coloring(C)
# Out:
# Graphics object consisting of 21 graphics primitives
# {1: [(6, 4), (5, 4), (3, 2), (1, 0)], 2: [(1, 3), (4, 5), (6, 7), (2, 3)], 3: [(3, 1), (4, 6), (5, 7), (2, 0)], 4: [(7, 5), (0, 1)], 5: [(7, 6), (0, 2)], 6: [(2, 1), (7, 4), (0, 3), (6, 5)], 7: [(1, 2), (4, 7), (3, 0), (5, 6)]}
# True
